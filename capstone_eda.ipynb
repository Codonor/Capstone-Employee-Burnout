# %%
import pandas as pd
import numpy as np

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Conor\\Documents\\Code Institute\\Capstone'

# %%
os.chdir(r"C:\Users\Conor\Documents\Code Institute\Capstone")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Conor\\Documents\\Code Institute\\Capstone'

# %%
df = pd.read_json("synthetic-employee-dataset-raw.json")

# %%
df.head()
# Out:
#     employee_id                       role job_level              department  \
# 0  SYN_00000000                                  Mid  Research & Development
# 1  SYN_00000001   Customer Success Manager   Manager  Research & Development
# 2  SYN_00000002   Administrative Assistant     Entry                      HR
# 3  SYN_00000003             Senior Manager   Manager  Research & Development
# 4  SYN_00000004         Anonymous Employee       Mid  Research & Development
#
#    tenure_months         salary  performance_score  satisfaction_score  \
# 0            169   79704.579059           0.632482            0.623746
# 1             54   29694.288831           0.538587            0.982556
# 2              1   62208.470185           0.624656            0.767200
# 3             31  236066.567114           0.959320            0.185888
# 4            131   37306.328156           0.677305            0.566706
#
# ...

# %%
df.shape
# Out:
# (849999, 31)

# %%
df.columns
# Out:
# Index(['employee_id', 'role', 'job_level', 'department', 'tenure_months',
#        'salary', 'performance_score', 'satisfaction_score', 'workload_score',
#        'team_sentiment', 'recent_feedback', 'communication_patterns',
#        'project_completion_rate', 'overtime_hours', 'training_participation',
#        'collaboration_score', 'technical_skills', 'soft_skills',
#        'email_sentiment', 'slack_activity', 'meeting_participation',
#        'goal_achievement_rate', 'stress_level', 'burnout_risk', 'left_company',
#        'turnover_reason', 'risk_factors_summary',
#        'turnover_probability_generated', 'persona_name',
#        'role_complexity_score', 'career_progression_score'],
#       dtype='object')

# %%
# View all columns for initial inspection
pd.set_option("display.max_columns", None)
df.head()
# Out:
#     employee_id                       role job_level              department  \
# 0  SYN_00000000                                  Mid  Research & Development
# 1  SYN_00000001   Customer Success Manager   Manager  Research & Development
# 2  SYN_00000002   Administrative Assistant     Entry                      HR
# 3  SYN_00000003             Senior Manager   Manager  Research & Development
# 4  SYN_00000004         Anonymous Employee       Mid  Research & Development
#
#    tenure_months         salary  performance_score  satisfaction_score  \
# 0            169   79704.579059           0.632482            0.623746
# 1             54   29694.288831           0.538587            0.982556
# 2              1   62208.470185           0.624656            0.767200
# 3             31  236066.567114           0.959320            0.185888
# 4            131   37306.328156           0.677305            0.566706
#
#    workload_score  team_sentiment  \
# 0        0.758117        0.662335
# ...

# %%
# Out:
# <module 'ntpath' from 'C:\\Users\\Conor\\anaconda3\\Lib\\ntpath.py'>
