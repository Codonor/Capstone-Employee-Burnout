# %%
# import relevant libraries
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Conor\\Documents\\Code Institute\\Capstone'

# %% [markdown]
# - Current working directory should read as 'C:\\Users\\Conor\\Documents\\Code Institute\\Capstone'

# %%
# Randomly sampled 100,000 lines of the df and saved it to .csv as processing power was too low on my computer to work with the full data.



# Load file 
df_full = pd.read_json("data/synthetic-employee-dataset-raw.json")

# Randomly sample 100,000 rows with random state for reproducibility 
df = df_full.sample(n=100000, random_state=42)

# Save sampled data for repeated use
df.to_csv("data/sampled_data.csv", index=False)
